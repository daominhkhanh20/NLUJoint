# %%
import pandas as pd 
import os 
import seaborn as sns

# %%
data = pd.read_csv('../assets/data/comet/train.csv')

# %%
data
# Out:
#                                                    text             intent  \
# 0                                    Kích thước bn shop       request#size
# 1                            Shop còn quây toyhouse ko?             inform
# 2                         Be rong dai bao nhieu ghe nay       request#size
# 3                         Còn khuyen mai 10% không shop        ask_confirm
# 4                      Jum là ghế nhún cho bé đúng ko ạ        ask_confirm
# ...                                                 ...                ...
# 6042  C oi thảm hàn quốc nhà mình có những mẫu nào g...      request#price
# 6043              Nếu mình mua 2 cái có dc giảm giá k ạ  request#promotion
# 6044       hàng chính hãng nutribaby plus đúng ko b ui?        ask_confirm
# 6045                         CHắc cũng tầm 3kg shop nhỉ        ask_confirm
# 6046                                       Bảo hành k b  request#guarantee
#
#                                                    tags
# ...

# %%
sns.countplot(data.intent)
# Out:
# <AxesSubplot:xlabel='intent', ylabel='count'>
